jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_870.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_871.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_872.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_873.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_874.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_875.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_876.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_877.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_878.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_879.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_88.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_880.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_881.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_882.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_883.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_884.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_885.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_886.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_887.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_888.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_889.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_89.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_890.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_891.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_892.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_893.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_894.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_895.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_896.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_897.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_898.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_899.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_9.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_90.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_900.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_901.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_902.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_903.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_904.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_905.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_906.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_907.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_908.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_909.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_91.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_910.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_911.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_912.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_913.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_914.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_915.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_916.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_917.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_918.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_919.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_92.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_920.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_921.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_922.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_923.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_924.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_925.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_926.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_927.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_928.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_929.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_93.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_930.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_931.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_932.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_933.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_934.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_935.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_936.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_937.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_938.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_939.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_94.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_940.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_941.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_942.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_943.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_944.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_945.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_946.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_947.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_948.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_949.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_95.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_950.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_951.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_952.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_953.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_954.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_955.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_956.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_957.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_958.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_959.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_96.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_960.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_961.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_962.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_963.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_964.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_965.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_966.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_967.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_968.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_969.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_97.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_970.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_971.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_972.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_973.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_974.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_975.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_976.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_977.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_978.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_979.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_98.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_980.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_981.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_982.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_983.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_984.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_985.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_986.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_987.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_988.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_989.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_99.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_990.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_991.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_992.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_993.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_994.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_995.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_996.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_997.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_998.jpg
#   inflating: /content/brain_tumor_data/Training/pituitary/Tr-pi_999.jpg

# %% [markdown]
# # EDA

# %%
import matplotlib.pyplot as plt
import os
import numpy as np
from sklearn.model_selection import train_test_split
from collections import Counter
from collections import defaultdict
import random
from torch.utils.data import Dataset
from PIL import Image

# %%
train_dir = "/content/brain_tumor_data/Training"
test_dir = "/content/brain_tumor_data/Testing"

# ---------------------------
# Count testing set per class
# ---------------------------

test_paths =  []
test_labels = []

test_classes = [
    cls for cls in os.listdir(test_dir)
    if os.path.isdir(os.path.join(test_dir, cls))
]

for label in test_classes:
    class_path = os.path.join(test_dir, label)

    for img_name in os.listdir(class_path):
        test_paths.append(os.path.join(class_path, img_name))
        test_labels.append(label)

test_class_counts = {
    cls: len(os.listdir(os.path.join(test_dir, cls)))
    for cls in test_classes
}

print("Testing:", test_class_counts)

# ---------------------------
# Collect training image paths and labels
# ---------------------------
image_paths = []
labels = []

train_classes = [
    cls for cls in os.listdir(train_dir)
    if os.path.isdir(os.path.join(train_dir, cls))
]

for label in train_classes:
    class_path = os.path.join(train_dir, label)

    for img_name in os.listdir(class_path):
        img_path = os.path.join(class_path, img_name)
        image_paths.append(img_path)
        labels.append(label)

# ---------------------------
# Stratified split
# ---------------------------
train_paths, val_paths, train_labels, val_labels = train_test_split(
    image_paths,
    labels,
    test_size=0.2,
    stratify=labels,
    random_state=42
)


# ---------------------------
# Create train and validation datasets
# ---------------------------

class MRIDataset(Dataset):
    def __init__(self, paths, labels, label_to_idx, transform=None):
        self.paths = paths
        self.labels = labels
        self.transform = transform
        self.label_to_idx = label_to_idx

    def __len__(self):
        return len(self.paths)

    def __getitem__(self, idx):
        image = Image.open(self.paths[idx]).convert("L")
        label = self.label_to_idx[self.labels[idx]]

        if self.transform:
            image = self.transform(image)

        return image, label

classes = sorted(set(labels))   # labels = original full dataset labels
label_to_idx = {cls: i for i, cls in enumerate(classes)}

print(label_to_idx)


# ---------------------------
# Count class distributions
# ---------------------------
original_counts = Counter(labels)
train_class_counts = Counter(train_labels)
val_class_counts = Counter(val_labels)

print("\nTraining set size:", len(train_paths))
print("Validation set size:", len(val_paths))

print("\nOriginal Training distribution Before Splitting:")
print(original_counts)

print("\nTraining distribution:")
print(train_class_counts)

print("\nValidation distribution:")
print(val_class_counts)

# ---------------------------
# Plot distributions
# ---------------------------
plt.figure(figsize=(18, 5))

plt.subplot(1, 3, 1)
plt.bar(test_class_counts.keys(), test_class_counts.values())
plt.title("Testing Data Distribution")
plt.xlabel("Class")
plt.ylabel("Number of Images")

plt.subplot(1, 3, 2)
plt.bar(train_class_counts.keys(), train_class_counts.values())
plt.title("Training Split Distribution")
plt.xlabel("Class")
plt.ylabel("Number of Images")

plt.subplot(1, 3, 3)
plt.bar(val_class_counts.keys(), val_class_counts.values())
plt.title("Validation Split Distribution")
plt.xlabel("Class")
plt.ylabel("Number of Images")

plt.tight_layout()
plt.show()
# Out:
# Testing: {'pituitary': 400, 'meningioma': 400, 'glioma': 400, 'notumor': 400}
# {'glioma': 0, 'meningioma': 1, 'notumor': 2, 'pituitary': 3}
#
# Training set size: 4480
# Validation set size: 1120
#
# Original Training distribution Before Splitting:
# Counter({'pituitary': 1400, 'meningioma': 1400, 'glioma': 1400, 'notumor': 1400})
#
# Training distribution:
# Counter({'pituitary': 1120, 'notumor': 1120, 'glioma': 1120, 'meningioma': 1120})
#
# Validation distribution:
# Counter({'glioma': 280, 'meningioma': 280, 'pituitary': 280, 'notumor': 280})

# %%
def show_random_images(paths, labels, num_per_class=3):

    # group images by class
    class_to_images = defaultdict(list)

    for path, label in zip(paths, labels):
        class_to_images[label].append(path)

    classes = list(class_to_images.keys())

    plt.figure(figsize=(num_per_class * 3, len(classes) * 3))

    plot_index = 1

    for cls in classes:
        images = class_to_images[cls]

        selected = random.sample(images, min(len(images), num_per_class))

        for img_path in selected:
            img = Image.open(img_path)

            plt.subplot(len(classes), num_per_class, plot_index)
            plt.imshow(img, cmap='gray')
            plt.title(cls)
            plt.axis('off')

            plot_index += 1

    plt.tight_layout()
    plt.show()

show_random_images(train_paths, train_labels, num_per_class=3)

# %% [markdown]
# # Data preprocessing

# %%
from torchvision import datasets
from torch.utils.data import DataLoader
from torchvision import transforms

# %%
from torchvision import transforms

train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5], std=[0.5])
])

val_transform = transforms.Compose([

    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5], std=[0.5])
])

test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5], std=[0.5])
])

train_dataset = MRIDataset(
    train_paths,
    train_labels,
    label_to_idx,
    transform=train_transform
)

val_dataset = MRIDataset(
    val_paths,
    val_labels,
    label_to_idx,
    transform=val_transform
)

test_dataset = MRIDataset(
    test_paths,
    test_labels,
    label_to_idx,
    transform=test_transform
)


# check shape

img, label = test_dataset[0]

print("testset shape:", img.shape)   # [1, 224, 224]


img, label = train_dataset[0]

print("trainset shape:", img.shape)   # should be [1, 224, 224]


img, label = val_dataset[0]

print("valset shape:", img.shape)   # should be [1, 224, 224]

# check label decoding

idx_to_label = {v: k for k, v in label_to_idx.items()}
# train
img, label_num = train_dataset[0]
print("train_labels[0] =", train_labels[0])
print("decoded label   =", idx_to_label[label_num])

# val
img, label_num = val_dataset[0]
print("val_labels[0]   =", val_labels[0])
print("decoded label   =", idx_to_label[label_num])

# test
img, label_num = test_dataset[0]
print("test_labels[0]  =", test_labels[0])
print("decoded label   =", idx_to_label[label_num])

# check augmentation
def show_augmentation(dataset, paths, index=0, num_versions=5):
    original_img = Image.open(paths[index])

    plt.figure(figsize=(3 * (num_versions + 1), 4))

    # original
    plt.subplot(1, num_versions + 1, 1)
    plt.imshow(original_img, cmap='gray')
    plt.title("Original")
    plt.axis("off")

    # augmented versions
    for i in range(num_versions):
        img, label = dataset[index]

        # undo normalization for display
        img = img * 0.5 + 0.5
        img = img.squeeze().numpy()

        plt.subplot(1, num_versions + 1, i + 2)
        plt.imshow(img, cmap='gray')
        plt.title(f"Aug {i+1}\n{idx_to_label[label]}")
        plt.axis("off")

    plt.tight_layout()
    plt.show()

show_augmentation(train_dataset, train_paths, index=0, num_versions=5)

img1, label1 = train_dataset[0]
img2, label2 = train_dataset[0]

print("Same label:", label1 == label2)
print("Exactly same tensor:", (img1 == img2).all().item())
# Out:
# testset shape: torch.Size([1, 224, 224])
# trainset shape: torch.Size([1, 224, 224])
# valset shape: torch.Size([1, 224, 224])
# train_labels[0] = pituitary
# decoded label   = pituitary
# val_labels[0]   = glioma
# decoded label   = glioma
# test_labels[0]  = pituitary
# decoded label   = pituitary
# Same label: True
# Exactly same tensor: False

# %% [markdown]
# # Improved CNN model

# %%
import torch
import torch.nn as nn
import copy

# %%
train_loader = DataLoader(
    train_dataset,
    batch_size=64,
    shuffle=True,
    num_workers=2,
    pin_memory=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=64,
    shuffle=False,
    num_workers=2,
    pin_memory=True
)

test_loader = DataLoader(
    test_dataset,
    batch_size=64,
    shuffle=False,
    num_workers=2,
    pin_memory=True
)

# %%
class ImprovedCNN(nn.Module):
    def __init__(self, num_classes=4):
        super().__init__()

        self.features = nn.Sequential(
            nn.Conv2d(1, 16, kernel_size=3, padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),

            nn.Conv2d(16, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),

            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),

            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),

        )

        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(128*14*14, 64),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(64, num_classes)
        )

    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)
        return x

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
model = ImprovedCNN(num_classes=4).to(device)
# Out:
# cuda

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.0007)


def train_one_epoch(model, dataloader, criterion, optimizer, device):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for batch_idx, (images, labels) in enumerate(dataloader):

        if batch_idx % 20 == 0:
            print(f"Batch {batch_idx}/{len(dataloader)}")

        images = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        outputs = model(images)
        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        running_loss += loss.item() * images.size(0)

        _, preds = torch.max(outputs, 1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)

    epoch_loss = running_loss / total
    epoch_acc = correct / total

    return epoch_loss, epoch_acc

# %%
def evaluate(model, dataloader, criterion, device):
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0

    with torch.no_grad():
        for images, labels in dataloader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            running_loss += loss.item() * images.size(0)

            _, preds = torch.max(outputs, 1)
            correct += (preds == labels).sum().item()
            total += labels.size(0)

    epoch_loss = running_loss / total
    epoch_acc = correct / total

    return epoch_loss, epoch_acc

# %%
num_epochs = 60

train_losses = []
train_accuracies = []


val_losses = []
val_accuracies = []

best_val_loss = float('inf')
best_val_acc = 0.0
best_train_acc = 0.0

best_model_wts = copy.deepcopy(model.state_dict())

patience = 8
counter = 0           # count epochs with no improvement
min_delta = 1e-4      # minimum improvement to be considered as better

for epoch in range(num_epochs):
    train_loss, train_acc = train_one_epoch(model, train_loader, criterion, optimizer, device)
    val_loss, val_acc = evaluate(model, val_loader, criterion, device)

    train_losses.append(train_loss)
    train_accuracies.append(train_acc)
    val_losses.append(val_loss)
    val_accuracies.append(val_acc)

    print(f"Epoch [{epoch+1}/{num_epochs}]")
    print(f"Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}")
    print(f"Val   Loss: {val_loss:.4f}, Val   Acc: {val_acc:.4f}")

    # save best model based on val accuracy
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_model_wts = copy.deepcopy(model.state_dict())
        torch.save(best_model_wts, '/content/best_baseline_model.pth')
        print("Best model updated!")

    # early stopping based on val loss
    if val_loss < best_val_loss - min_delta:
        best_val_loss = val_loss
        counter = 0
    else:
        counter += 1
        print(f"No val_loss improvement for {counter} epoch(s).")

    # start early stopping only after some epochs
    if epoch >= 10 and counter >= patience:
        print("Early stopping triggered.")
        break

model.load_state_dict(best_model_wts)
print(f"Loaded best model with validation accuracy: {best_val_acc:.4f}")
# Out:
# Batch 0/70
# Batch 20/70
# Batch 40/70
# Batch 60/70
# Epoch [1/60]
# Train Loss: 1.1599, Train Acc: 0.6199
# Val   Loss: 0.6263, Val   Acc: 0.7545
# Best model updated!
# Batch 0/70
# Batch 20/70
# Batch 40/70
# Batch 60/70
# Epoch [2/60]
# Train Loss: 0.5961, Train Acc: 0.7779
# Val   Loss: 0.4412, Val   Acc: 0.8286
# Best model updated!
# Batch 0/70
# Batch 20/70
# Batch 40/70
# Batch 60/70
# Epoch [3/60]
# Train Loss: 0.4987, Train Acc: 0.8045
# Val   Loss: 0.4068, Val   Acc: 0.8518
# Best model updated!
# Batch 0/70
# Batch 20/70
# Batch 40/70
# Batch 60/70
# Epoch [4/60]
# Train Loss: 0.4407, Train Acc: 0.8339
# Val   Loss: 0.3450, Val   Acc: 0.8714
# Best model updated!
# Batch 0/70
# Batch 20/70
# Batch 40/70
# Batch 60/70
# Epoch [5/60]
# Train Loss: 0.3675, Train Acc: 0.8623
# Val   Loss: 0.3280, Val   Acc: 0.8839
# Best model updated!
# Batch 0/70
# Batch 20/70
# Batch 40/70
# Batch 60/70
# Epoch [6/60]
# Train Loss: 0.3210, Train Acc: 0.8737
# Val   Loss: 0.2658, Val   Acc: 0.9045
# Best model updated!
# Batch 0/70
# Batch 20/70
# Batch 40/70
# Batch 60/70
# Epoch [7/60]
# Train Loss: 0.3263, Train Acc: 0.8679
# Val   Loss: 0.2598, Val   Acc: 0.9009
# Batch 0/70
# Batch 20/70
# Batch 40/70
# Batch 60/70
# Epoch [8/60]
# Train Loss: 0.2675, Train Acc: 0.8922
# Val   Loss: 0.2928, Val   Acc: 0.8982
# No val_loss improvement for 1 epoch(s).
# Batch 0/70
# Batch 20/70
# Batch 40/70
# Batch 60/70
# Epoch [9/60]
# Train Loss: 0.2629, Train Acc: 0.8969
# Val   Loss: 0.3425, Val   Acc: 0.8696
# No val_loss improvement for 2 epoch(s).
# Batch 0/70
# Batch 20/70
# Batch 40/70
# Batch 60/70
# Epoch [10/60]
# Train Loss: 0.2366, Train Acc: 0.9067
# Val   Loss: 0.2306, Val   Acc: 0.9161
# Best model updated!
# Batch 0/70
# Batch 20/70
# Batch 40/70
# Batch 60/70
# Epoch [11/60]
# Train Loss: 0.2215, Train Acc: 0.9132
# Val   Loss: 0.2153, Val   Acc: 0.9223
# Best model updated!
# Batch 0/70
# Batch 20/70
# Batch 40/70
# Batch 60/70
# Epoch [12/60]
# Train Loss: 0.2021, Train Acc: 0.9183
# Val   Loss: 0.3481, Val   Acc: 0.8795
# No val_loss improvement for 1 epoch(s).
# Batch 0/70
# Batch 20/70
# Batch 40/70
# Batch 60/70
# Epoch [13/60]
# Train Loss: 0.1889, Train Acc: 0.9304
# Val   Loss: 0.3916, Val   Acc: 0.8688
# No val_loss improvement for 2 epoch(s).
# Batch 0/70
# Batch 20/70
# Batch 40/70
# Batch 60/70
# Epoch [14/60]
# Train Loss: 0.2010, Train Acc: 0.9176
# Val   Loss: 0.2220, Val   Acc: 0.9241
# Best model updated!
# No val_loss improvement for 3 epoch(s).
# Batch 0/70
# Batch 20/70
# Batch 40/70
# Batch 60/70
# Epoch [15/60]
# Train Loss: 0.1749, Train Acc: 0.9304
# Val   Loss: 0.2253, Val   Acc: 0.9214
# No val_loss improvement for 4 epoch(s).
# Batch 0/70
# Batch 20/70
# Batch 40/70
# Batch 60/70
# Epoch [16/60]
# Train Loss: 0.1685, Train Acc: 0.9339
# Val   Loss: 0.2358, Val   Acc: 0.9205
# No val_loss improvement for 5 epoch(s).
# Batch 0/70
# Batch 20/70
# Batch 40/70
# Batch 60/70
# Epoch [17/60]
# Train Loss: 0.1408, Train Acc: 0.9395
# Val   Loss: 0.2185, Val   Acc: 0.9375
# Best model updated!
# No val_loss improvement for 6 epoch(s).
# Batch 0/70
# Batch 20/70
# Batch 40/70
# Batch 60/70
# Epoch [18/60]
# Train Loss: 0.1620, Train Acc: 0.9373
# Val   Loss: 0.2114, Val   Acc: 0.9330
# Batch 0/70
# Batch 20/70
# Batch 40/70
# Batch 60/70
# Epoch [19/60]
# Train Loss: 0.1312, Train Acc: 0.9496
# Val   Loss: 0.2564, Val   Acc: 0.9152
# No val_loss improvement for 1 epoch(s).
# Batch 0/70
# Batch 20/70
# Batch 40/70
# Batch 60/70
# Epoch [20/60]
# Train Loss: 0.1181, Train Acc: 0.9542
# Val   Loss: 0.1862, Val   Acc: 0.9339
# Batch 0/70
# Batch 20/70
# Batch 40/70
# Batch 60/70
# Epoch [21/60]
# Train Loss: 0.1193, Train Acc: 0.9516
# Val   Loss: 0.1936, Val   Acc: 0.9304
# No val_loss improvement for 1 epoch(s).
# Batch 0/70
# Batch 20/70
# Batch 40/70
# Batch 60/70
# Epoch [22/60]
# Train Loss: 0.1207, Train Acc: 0.9498
# Val   Loss: 0.2511, Val   Acc: 0.9348
# No val_loss improvement for 2 epoch(s).
# Batch 0/70
# Batch 20/70
# Batch 40/70
# Batch 60/70
# Epoch [23/60]
# Train Loss: 0.1166, Train Acc: 0.9563
# Val   Loss: 0.1938, Val   Acc: 0.9455
# Best model updated!
# No val_loss improvement for 3 epoch(s).
# Batch 0/70
# Batch 20/70
# Batch 40/70
# Batch 60/70
# Epoch [24/60]
# Train Loss: 0.1156, Train Acc: 0.9576
# Val   Loss: 0.1838, Val   Acc: 0.9393
# Batch 0/70
# Batch 20/70
# Batch 40/70
# Batch 60/70
# Epoch [25/60]
# Train Loss: 0.0946, Train Acc: 0.9643
# Val   Loss: 0.1926, Val   Acc: 0.9411
# No val_loss improvement for 1 epoch(s).
# Batch 0/70
# Batch 20/70
# Batch 40/70
# Batch 60/70
# Epoch [26/60]
# Train Loss: 0.1072, Train Acc: 0.9565
# Val   Loss: 0.2124, Val   Acc: 0.9402
# No val_loss improvement for 2 epoch(s).
# Batch 0/70
# Batch 20/70
# Batch 40/70
# Batch 60/70
# Epoch [27/60]
# Train Loss: 0.0955, Train Acc: 0.9612
# Val   Loss: 0.1833, Val   Acc: 0.9482
# Best model updated!
# Batch 0/70
# Batch 20/70
# Batch 40/70
# Batch 60/70
# Epoch [28/60]
# Train Loss: 0.0990, Train Acc: 0.9598
# Val   Loss: 0.2181, Val   Acc: 0.9473
# No val_loss improvement for 1 epoch(s).
# Batch 0/70
# Batch 20/70
# Batch 40/70
# Batch 60/70
# Epoch [29/60]
# Train Loss: 0.0903, Train Acc: 0.9612
# Val   Loss: 0.2664, Val   Acc: 0.9259
# No val_loss improvement for 2 epoch(s).
# Batch 0/70
# Batch 20/70
# Batch 40/70
# Batch 60/70
# Epoch [30/60]
# Train Loss: 0.0940, Train Acc: 0.9609
# Val   Loss: 0.1759, Val   Acc: 0.9482
# Batch 0/70
# Batch 20/70
# Batch 40/70
# Batch 60/70
# Epoch [31/60]
# Train Loss: 0.0863, Train Acc: 0.9614
# Val   Loss: 0.2694, Val   Acc: 0.9339
# No val_loss improvement for 1 epoch(s).
# Batch 0/70
# Batch 20/70
# Batch 40/70
# Batch 60/70
# Epoch [32/60]
# Train Loss: 0.0860, Train Acc: 0.9661
# Val   Loss: 0.1672, Val   Acc: 0.9536
# Best model updated!
# Batch 0/70
# Batch 20/70
# Batch 40/70
# Batch 60/70
# Epoch [33/60]
# Train Loss: 0.0765, Train Acc: 0.9696
# Val   Loss: 0.2828, Val   Acc: 0.9348
# No val_loss improvement for 1 epoch(s).
# Batch 0/70
# Batch 20/70
# Batch 40/70
# Batch 60/70
# Epoch [34/60]
# Train Loss: 0.0807, Train Acc: 0.9672
# Val   Loss: 0.2335, Val   Acc: 0.9509
# No val_loss improvement for 2 epoch(s).
# Batch 0/70
# Batch 20/70
# Batch 40/70
# Batch 60/70
# Epoch [35/60]
# Train Loss: 0.0728, Train Acc: 0.9692
# Val   Loss: 0.2073, Val   Acc: 0.9545
# Best model updated!
# No val_loss improvement for 3 epoch(s).
# Batch 0/70
# Batch 20/70
# Batch 40/70
# Batch 60/70
# Epoch [36/60]
# Train Loss: 0.0666, Train Acc: 0.9725
# Val   Loss: 0.2997, Val   Acc: 0.9384
# No val_loss improvement for 4 epoch(s).
# Batch 0/70
# Batch 20/70
# Batch 40/70
# Batch 60/70
# Epoch [37/60]
# Train Loss: 0.0793, Train Acc: 0.9701
# Val   Loss: 0.2018, Val   Acc: 0.9509
# No val_loss improvement for 5 epoch(s).
# Batch 0/70
# Batch 20/70
# Batch 40/70
# Batch 60/70
# Epoch [38/60]
# Train Loss: 0.0759, Train Acc: 0.9663
# Val   Loss: 0.2243, Val   Acc: 0.9527
# No val_loss improvement for 6 epoch(s).
# Batch 0/70
# Batch 20/70
# Batch 40/70
# Batch 60/70
# Epoch [39/60]
# Train Loss: 0.0563, Train Acc: 0.9779
# Val   Loss: 0.2216, Val   Acc: 0.9536
# No val_loss improvement for 7 epoch(s).
# Batch 0/70
# Batch 20/70
# Batch 40/70
# Batch 60/70
# Epoch [40/60]
# Train Loss: 0.0687, Train Acc: 0.9712
# Val   Loss: 0.1859, Val   Acc: 0.9554
# Best model updated!
# No val_loss improvement for 8 epoch(s).
# Early stopping triggered.
# Loaded best model with validation accuracy: 0.9554

# %%
# !cp /content/best_baseline_model.pth /content/drive/MyDrive/

# %%
torch.save(train_accuracies, '/content/drive/MyDrive/train_acc.pth')
# torch.save(train_eval_accuracies, '/content/drive/MyDrive/train_eval_acc.pth')
torch.save(val_accuracies, '/content/drive/MyDrive/val_acc.pth')

# %%
plt.plot(train_losses, label='Train Losses')
plt.plot(val_losses, label='Val Losses')
plt.legend()
plt.title("Losses Curve")
plt.show()

plt.plot(train_accuracies, label='Train Acc')
plt.plot(val_accuracies, label='Val Acc')
plt.legend()
plt.title("Accuracy Curve")
plt.show()

# %% [markdown]
# Evaluation

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import seaborn as sns

# %%
def get_predictions(model, dataloader, device):
    model.eval()

    all_preds = []
    all_labels = []

    with torch.no_grad():
        for images, labels in dataloader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            _, preds = torch.max(outputs, 1)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    return np.array(all_labels), np.array(all_preds)

# %%
def evaluate_metrics(model, dataloader, device):
    y_true, y_pred = get_predictions(model, dataloader, device)

    acc = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted')
    recall = recall_score(y_true, y_pred, average='weighted')
    f1 = f1_score(y_true, y_pred, average='weighted')

    cm = confusion_matrix(y_true, y_pred)

    print(f"Accuracy : {acc:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall   : {recall:.4f}")
    print(f"F1-score : {f1:.4f}")

    return cm

# %%
cm = evaluate_metrics(model, test_loader, device)
# Out:
# Accuracy : 0.8931
# Precision: 0.8996
# Recall   : 0.8931
# F1-score : 0.8920

# %%
def plot_confusion_matrix(cm, classes, normalize=False):
    plt.figure(figsize=(6,5))

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1, keepdims=True)
        fmt = '.2f'
        title = "Normalized Confusion Matrix"
    else:
        fmt = 'd'
        title = "Confusion Matrix"

    sns.heatmap(cm, annot=True, fmt=fmt, cmap='Blues',
                xticklabels=classes, yticklabels=classes)

    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.title(title)
    plt.show()

# %%
class_names = list(label_to_idx.keys())
plot_confusion_matrix(cm, class_names, normalize=True)
